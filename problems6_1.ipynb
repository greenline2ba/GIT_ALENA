# %%
string ="skdhiushfudsgfuds1568456415646456fuds"
print(len(string))
# Out:
# 21

# %%
import re

# %%
cisla = re.count(string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cisla = re.count(string)
#
# AttributeError: module 're' has no attribute 'count'

# %%
print(cisla)
# Out:
# []
