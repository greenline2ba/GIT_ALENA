# %%
pravidelny_vklad =50
urokova_sadzba_rocne= 0.05
urokova_sadzba_per_month= urokova_sadzba_rocne / 12
pocet_mesiacov= 10*12

# %%
FV = pravidelny_vklad * (((1 + urokova_sadzba_per_month) ** pocet_mesiacov - 1) / urokova_sadzba_per_month)
print(FV)
# Out:
# 7764.1139722833595
